# %%
import pandas as pd

# %%
##read function can be html, excel, csv, text, json etc.
tables = pd.read_csv(r"/Users/Jason/Downloads/list of largest companies.csv") 
tables
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
##For Excel you can use sheet_name to get exact sheet wanted instead of the first sheet.
import pandas as pd

# %%
tables = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
tables
# Out:
#    EmployeeID FirstName    LastName  Age  Gender            JobTitle  Salary  \
# 0        1001       Jim     Halpert   30    Male            Salesman   45000
# 1        1002       Pam     Beasley   30  Female        Receptionist   36000
# 2        1003    Dwight     Schrute   29    Male            Salesman   63000
# 3        1004    Angela      Martin   31  Female          Accountant   47000
# 4        1005      Toby  Flenderson   32    Male                  HR   50000
# 5        1006   Michael       Scott   35    Male    Regional Manager   65000
# 6        1007  Meredith      Palmer   32  Female  Supplier Relations   41000
# 7        1008   Stanley      Hudson   38    Male            Salesman   48000
# 8        1009     Kevin      Malone   31    Male          Accountant   42000
#
#    StartDate    EndDate  IF  IFS
# 0 2001-11-02 2015-09-06 NaN  NaN
# 1 1999-10-03 2015-10-10 NaN  NaN
# 2 2000-07-04 2017-09-08 NaN  NaN
# 3 2000-01-05 2015-12-03 NaN  NaN
# ...

# %%
##Import max rows and columns 
import pandas as pd

# %%
##read function can be html, excel, csv, text, json etc.
tables = pd.read_csv(r"/Users/Jason/Downloads/list of largest companies.csv")
tables
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
##displeay max row and columns
pd.set_option('display.max.rows', 100)
pd.set_option('display.max.columns', 7)
tables
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
##Print data frame information
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  9 non-null      int64
#  1   FirstName   9 non-null      object
#  2   LastName    9 non-null      object
#  3   Age         9 non-null      int64
#  4   Gender      9 non-null      object
#  5   JobTitle    9 non-null      object
#  6   Salary      9 non-null      int64
#  7   StartDate   9 non-null      datetime64[ns]
#  8   EndDate     9 non-null      datetime64[ns]
#  9   IF          0 non-null      float64
#  10  IFS         0 non-null      float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(4)
# memory usage: 924.0+ bytes

# %%
##Print data frame shape
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df.shape
# Out:
# (9, 11)

# %%
##Print first 10 rows
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df.head(10)
# Out:
#    EmployeeID FirstName    LastName  ...    EndDate  IF IFS
# 0        1001       Jim     Halpert  ... 2015-09-06 NaN NaN
# 1        1002       Pam     Beasley  ... 2015-10-10 NaN NaN
# 2        1003    Dwight     Schrute  ... 2017-09-08 NaN NaN
# 3        1004    Angela      Martin  ... 2015-12-03 NaN NaN
# 4        1005      Toby  Flenderson  ... 2017-08-30 NaN NaN
# 5        1006   Michael       Scott  ... 2013-09-11 NaN NaN
# 6        1007  Meredith      Palmer  ... 2013-10-04 NaN NaN
# 7        1008   Stanley      Hudson  ... 2015-04-22 NaN NaN
# 8        1009     Kevin      Malone  ... 2011-09-14 NaN NaN
#
# [9 rows x 11 columns]

# %%
##Print last 4 rows
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df.tail(4)
# Out:
#    EmployeeID FirstName LastName  ...    EndDate  IF IFS
# 5        1006   Michael    Scott  ... 2013-09-11 NaN NaN
# 6        1007  Meredith   Palmer  ... 2013-10-04 NaN NaN
# 7        1008   Stanley   Hudson  ... 2015-04-22 NaN NaN
# 8        1009     Kevin   Malone  ... 2011-09-14 NaN NaN
#
# [4 rows x 11 columns]

# %%
##Display Age data only
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df['Age']
# Out:
# 0    30
# 1    30
# 2    29
# 3    31
# 4    32
# 5    35
# 6    32
# 7    38
# 8    31
# Name: Age, dtype: int64

# %%
##display information for row in index 1
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df.loc[1]
# Out:
# EmployeeID                   1002
# FirstName                     Pam
# LastName                  Beasley
# Age                            30
# Gender                     Female
# JobTitle             Receptionist
# Salary                      36000
# StartDate     1999-10-03 00:00:00
# EndDate       2015-10-10 00:00:00
# IF                            NaN
# IFS                           NaN
# Name: 1, dtype: object

# %%
##display information for integer location
import pandas as pd

# %%
df = pd.read_excel(r"/Users/Jason/Downloads/Formula Excel Template.xlsx", sheet_name="IF-IFS")
df.iloc[2]
# Out:
# EmployeeID                   1003
# FirstName                  Dwight
# LastName                  Schrute
# Age                            29
# Gender                       Male
# JobTitle                 Salesman
# Salary                      63000
# StartDate     2000-07-04 00:00:00
# EndDate       2017-09-08 00:00:00
# IF                            NaN
# IFS                           NaN
# Name: 2, dtype: object
